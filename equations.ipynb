# %% [markdown]
# $$\min_\theta \ \frac{1}{N}\sum_{i=1}^{N} \mathcal{L}\!\big(R(\theta;\, \pi_i),\, I_i\big)$$

# %% [markdown]
# Both methods solve exactly the same minimization. They differ in the parameterization of 𝜽 and the implementation of 𝑹.
#
# Therefore, NeRF vs GS is a comparison of two optimization formulations of the same problem:
#
# * The data are 𝑵 posed images (𝝅_𝒊,𝑰_𝒊 ).
# * The objective is the average photometric loss between a rendered image and its ground truth.
# * The decision variable is 𝜽, the scene parameters.
# * The operator 𝑹 takes a scene description and a camera pose and returns the image that scene would produce from that pose.
# * The only requirement on 𝑹 is that it be differentiable with respect to 𝜽, so gradients of 𝓛 flow back into 𝜽 and a first-order optimizer can update.

# %% [markdown]
# $\partial \mathcal{L} / \partial \theta$

# %% [markdown]
# $\nabla_\theta \mathcal{L}$

# %% [markdown]
# $\pi_i$

# %% [markdown]
# $\pi$
